# %%
import pandas as pd

# %%
mydf=pd.read_csv("/content/mydf.csv")
mydf
# Out:
#     Unnamed: 0   Names Initials      SEM1  SEM2       SEM3 Grade  Placed  \
# 0            0     Joe        K  9.800000  10.0   9.900000    A+       1
# 1            1  Rajesh        M  8.900000   9.1   9.300000     A       1
# 2            2  Kissan        V  9.900000   9.8  10.000000     A       0
# 3            3    Mary        N  7.700000   8.0   8.992857     B       0
# 4            4    Jeen        K  9.800000   9.1   9.900000    A+       1
# 5            5     Raj        M  8.900000   9.1   9.300000     A       1
# 6            6  Hassan        V  9.900000   9.0   9.200000     A       1
# 7            7    Mari        N  7.700000   8.0   7.100000     B       1
# 8            8    Jess        K  8.992857   9.1   9.900000    A+       1
# 9            9  Rajini        M  8.992857   9.1   9.300000     A       0
# 10          10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11          11    Maya        N  7.700000   8.0   7.100000     B       0
# ...

# %%
import seaborn as sns

# %%
#lineplot
pl=sns.lineplot(x="Names",y="SEM1",data=mydf)

# %%
#relplot
sns.relplot(
    data=mydf,
    x="SEM1",y="Names",col="Placed")
#col==> Graphs are separated based on this column

# %%
#create a relational plot using age as y axis index as x axis seperated by class
#diabetes.xlss
dfe=pd.read_excel("/content/diabetes.xlsx")
dfe['Index']=range(1,769)
sns.relplot(
    data=dfe,
    x="Index",y="age",col="class")
dfe
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  Index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %%
 df4=sns.load_dataset("tips")
 df4
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=df4,x="total_bill",y="tip",hue="smoker",style="time",palette="bright")
#hue- creating difference based on a column via colors

# %%
sns.relplot(data=df4,x="total_bill",y="tip",hue="sex")

# %%
sns.relplot(data=df4,x="total_bill",y="tip",hue="size",style="time",palette="bright")
#hue- creating difference based on a column via colors

# %%
dj=sns.load_dataset("dowjones")
dj
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
sns.relplot(data=dj,x="Date",y="Price",kind="line")

# %%
fmri=sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fmri,x="timepoint",y="signal")

# %%
#catplot- category wise plot based on y
sns.catplot(data=fmri,x="timepoint",y="signal")

# %%
sns.catplot(data=fmri,x="timepoint",y="signal",kind="box",hue="event")

# %%
gama=sns.load_dataset('gammas')
gama
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-de3d94665413> in <cell line: 1>()
# ----> 1 gama=sns.load_dataset('gammas')
#       2 gama
#
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     571         if not os.path.exists(cache_path):
#     572             if name not in get_dataset_names():
# --> 573                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     574             urlretrieve(url, cache_path)
#     575         full_path = cache_path
#
# ValueError: 'gammas' is not one of the example datasets.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#diamonds
dia=sns.load_dataset('diamonds')
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.relplot(data=dia,x="carat",y="price",hue="color",style="depth",palette="bright")

# %%
pl=sns.lineplot(x="price",y="carat",data=dia)

# %%
sns.boxplot(data=dia, x="price", y="carat")
# Out:
# <Axes: xlabel='price', ylabel='carat'>

# %%
sns.boxplot(x="cut", y="price", hue="clarity", data=dia, palette="bright")
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.histplot(dia["carat"], bins=30,  color="blue")
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %%
#mpg
m=sns.load_dataset("mpg")
m
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.histplot(data=m["mpg"], bins=30,  color="teal")
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.boxplot(x="origin", y="mpg", data=m, palette="pastel")
# Out:
# <ipython-input-18-554d017ec5c5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="origin", y="mpg", data=m, palette="pastel")
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.scatterplot(x="horsepower", y="mpg", data=m, color="pink")
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
import seaborn as sns
